# %% [markdown]
# <a href="https://colab.research.google.com/github/aditibakaya/Cognorise-Infotech/blob/main/RED_WINE_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 102             8.1             0.545         0.18             1.9      0.080
# 1077            8.6             0.370         0.65             6.4      0.080
# 910             9.3             0.380         0.48             3.8      0.132
# 409            12.5             0.460         0.49             4.5      0.070
# 958             6.4             0.570         0.12             2.3      0.120
# 1226            7.5             0.580         0.03             4.1      0.080
# 473             9.9             0.350         0.55             2.1      0.062
# 203             7.0             0.420         0.35             1.6      0.088
# 567             8.7             0.700         0.24             2.5      0.226
# 1317            9.9             0.440         0.46             2.2      0.091
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corr_data = df.corr()
plt.figure(figsize = (9,9))
sns.heatmap(corr_data, cbar = True, square = True, annot = True, fmt = '.2f', cmap = 'coolwarm')
plt.title('correlation Heatmap Wine')
# Out:
# Text(0.5, 1.0, 'correlation Heatmap Wine')

# %% [markdown]
# *italicized text*

# %%
sns.catplot(x = 'quality', data=df, kind = 'count')
plt.title('wine qty. in every quality category')
# Out:
# Text(0.5, 1.0, 'wine qty. in every quality category')

# %%
sns.barplot(x='quality', y='volatile acidity',data = df,color='red')
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(x='quality', y='alcohol', data= df, color = 'black')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
df.plot(kind='box', subplots=True, layout=(4,4), sharex = False)
# Out:
# fixed acidity              Axes(0.125,0.712609;0.168478x0.167391)
# volatile acidity        Axes(0.327174,0.712609;0.168478x0.167391)
# citric acid             Axes(0.529348,0.712609;0.168478x0.167391)
# residual sugar          Axes(0.731522,0.712609;0.168478x0.167391)
# chlorides                  Axes(0.125,0.511739;0.168478x0.167391)
# free sulfur dioxide     Axes(0.327174,0.511739;0.168478x0.167391)
# total sulfur dioxide    Axes(0.529348,0.511739;0.168478x0.167391)
# density                 Axes(0.731522,0.511739;0.168478x0.167391)
# pH                          Axes(0.125,0.31087;0.168478x0.167391)
# sulphates                Axes(0.327174,0.31087;0.168478x0.167391)
# alcohol                  Axes(0.529348,0.31087;0.168478x0.167391)
# quality                  Axes(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %%
df['fixed acidity'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.hist(figsize=(10,10),bins=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
